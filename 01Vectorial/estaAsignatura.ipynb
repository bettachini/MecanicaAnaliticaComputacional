# %% [markdown]
# # Mecánica analítica computacional

# %% [markdown]
# [![DIIT - UNLaM](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2023 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# ## ¿Por qué esta asignatura se llama _Mecánica analítica computacional_?

# %% [markdown]
# - El nombre oficial es _Mecánica General_
#     - Uno que explique menos de que trata no podía imaginarse en una carrera de _Ingeniería mecánica_...
#     - Por esa razón en el _nuevo plan_ se llama **Mecánica analítica computacional**
# - Mecánica Analítica
#     - La física de un sistema de cuerpos puede resolverse en forma **vectorial**, como hicieron en Física I,
#     - o haciendo balance de **energías** (cinética, potencial, etc), como también hicieron en FI.
#     - Este último enfoque, el **analítico** es mucho **más poderoso** de lo que vieron en FI.
#     - Mejor que explicar ahora que esto **ahorra mucho trabajo** es aprenderlo en las próximas clases y **disfrutar** de esforzarse menos.

# %% [markdown]
# ## La asignatura _Mecánica General_ del plan actual

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/correlativas.png](data:image/png;base64,...)

# %% [markdown]
# - **Nexo** entre asignaturas:
#     - básicas: las instrumenta (las usa como herramientas)
#     - aplicadas: les proveé herramientas (en este caso, de la mecánica análitica)
# - Objetivo: tras cursarle ser capaz de calcular para **cualquier sistema de cuerpos rígidos**
#     - **dinámica** de cada parte
#     - **esfuerzos** estas partes (fuerzas, torques, tracciones, torsiones, etc.)
# - En un curso tradicional de mecánica analítica
#     - se llega hasta producir las **ecuaciones diferenciales** para lo anterior,
#     - pero se puede ir más lejos usando **herramientas** que no se suelen emplear en el aula

# %% [markdown]
# ## Siglo XIX | Únicas herramientas: pizarrón y papel

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/1930s-1940s-man-teacher-professor-vintage-images.jpg](data:image/png;base64,...)
#
# Professor at blackboard c.1935

# %% [markdown]
# - Alumnos y docentes pierden tiempo (y se aburren) copiando una y otra vez las mismas cosas:
#     - De libros (**papel**) el profesor **copia** teoría y ejemplos de resolución al **pizarrón**.
#     - Del **pizarrón** el alumno copia a su cuaderno de **papel** ambos.
#     - Cada vez que, en **papel**, empieza un nuevo ejercicio vuelven a resolverse idénticos modelos y cálculos.

# %% [markdown]
# ## 1970s | Electrónica en el aula

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/reglaCalculadora.jpg](data:image/png;base64,...)

# %% [markdown]
# - Los cálculos aritméticos y trigonométricos podían asistirse de tablas de logaritmos y la regla de cálculo.
# - La calculadora de bolsillo redujo el tiempo y esfurzo que esto requería.

# %% [markdown]
# ## 1990s | La computadora en el aula

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/systemsEngineering.png](data:image/png;base64,...)
#
# Control Systems Engineering, University of West England, Bristol, Reino Unido, 2012

# %% [markdown]
# - La revolución de la computadora personal pasó de largo a las aulas, nunca fue realmente aprovechada:
#     - ¿Se la usa para **proyectar diapositivas** o videos? Eso es reducirle a ser otro **pizarrón** o proyector de películas, tecnologías que le antecedieron.
#     - ¿Es un mero procesador de palabras? ¿Una planilla de cálculo? Mero- reemplazos del papel para escribir y hacer cuentas aritméticas.
#     - Quién solo usa así la computadora en la ingeniería del **siglo XXI** tiene aún la **mentalidad del siglo XIX**.
#     - En el **siglo XX** la computadora digital fue **inventada** justamente para resolver problemas de **ingeniería**.

# %% [markdown]
# ## Cálculo numérico

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/01Vectorial/estaFigs/vbush_overvw.gif](data:image/png;base64,...)
#
# [El 'analizador diferencial' inventado por el ingeniero Vannevar Bush y finalizado en 1931 por su equipo en el Massachusetts Institute of Technology (MIT) en Boston, Estados Unidos de América.](https://ub.fnwi.uva.nl/computermuseum/vbush_tbl.html)

# %% [markdown]
# - El análisis numérico, que conocen de la asignatura _Cálculo numérico_, existe desde [tiempos babilónicos](https://en.wikipedia.org/wiki/Numerical_analysis) cuando lo realizaban en tabletas de arcilla.
#     - Hacer cálculo numérico **en papel**, es seguir en los tiempos de la arcilla, **nadie en su sano juicio** lo hace manualmente.
# - Antes de la computadora digital se inventaron máquinas mecánicas y/o eléctricas para hacer automatizar el cálculo numérico
#     - No automatizarle lo hace laborioso y propenso a errores.
#     - El "analizador diferencial" mostrado arriba es un ejemplo que recibe su nombre por resolver problemas del **análisis diferencial** (derivadas, integrales), el empleo más usual del cálculo numérico.
# - Desde **mitad del s.XX** el cálculo numérico se realiza en **computadoras** digitales.
#     - La herramienta es fundamental en la ingeniería.
#     - No enseñar a los alumnos como explotar la computadora para esto es atentar contra su formación.

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/01Vectorial/estaFigs/puhzo1k4xe371.jpg](data:image/png;base64,...)
# [Nijolė Jadzevičiūtė, operadora de una supercomputadora БЭСМ-6, Vilna, Unión de Repúblicas Socialistas Soviéticas, 1974](https://i.redd.it/puhzo1k4xe371.jpg)

# %% [markdown]
# ## Álgebra computacional

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/01Vectorial/estaFigs/ucarecdn.jpeg](data:image/png;base64,...)
#
# Integración simbólica en [Macsyma](https://en.wikipedia.org/wiki/Macsyma), creado en 1968 es uno de los sistemas de álgebra computacional más antigüos aún en uso.

# %% [markdown]
# - A principios de los 1960s varios fisicos, como el Nobel [Martinus Veltman](https://en.wikipedia.org/wiki/Schoonschip), escribieron en FORTRAN o LISP [sistemas de álgebra computacional](https://en.wikipedia.org/wiki/Computer_algebra_system) para:
#     - manipular expresiones matemáticas de igual forma que se hace manualmente
#     - realizar automáticamente simplificaciones
#     - hacer transformadas de Fourier y Laplace
#     - calcular expansiones en series, y la suma de sus truncamientos
#     - hacer integración indefinida y con límites,
#     - realizar operaciones matriciales, etc.

# %% [markdown]
# ## Mecánica analítica **computacional**

# %% [markdown]
# - Quienes cursan _Mecánica analítica computacional_...
#     - ...ya aprobaron la __escuela primaria__:
#         - Demostraron que entienden y pueden hacer cálculos arítméticos manualmente.
#         - Hoy resuelven sus cálculos aritméticos más rápido y con menos errores en una __calculadora de bolsillo__.
#     - ...ya aprobaron en la __universidad__ asignaturas de álgebra y análisis matemático:
#         - Demostraron que entienden y pueden hacer cálculos integral y diferencial manualmente así como cálculos espaciales (vectoriales) y matriciales.
#         - A partir de hoy realizarán los mísmos más rápido y con menos errores utilizando un **sistema de álgebra computacional**.
# - La computadora puede hacer más que cálculo numérico para aliviar el esfuerzo que el ingeniero al resolver un problema matemático.
#     - Puede también realizar operaciones de álgebra y análisis simbólicos
#     - En este curso la utilizaremos también para obtener las ecuaciones diferenciales para la dinámica de sistemas de cuerpos rígidos.

# %% [markdown]
# ## Código para resolver problemas de mecánica

# %% [markdown]
# - Escribiremos código del lenguaje de programación general [Python](https://www.python.org/)
# - Escribir código $\neq$ programar
#     - **Programar**: Saber cómo analizar y modelar matemáticamente un problema (lógica), idear y comparar alternativas y saber calcular cual es la mejor considerando contexto de uso, restricciones, arquitectura del sistema informático, así como cuestiones de interfaz con el operador humano, etc.
#         - Requiere **bastante** estudio y esfuerzo.
#         - Todo estudiante de ingeniería **puede** aprender a programa.
#     - **Escribir código**: Plasmar una solución en un lenguaje de programación particular.
#         - Requiere **poco** estudio y esfuerzo.
#         - Todo estudiante de ingeniería **DEBE** aprender a escribir código.
# - Usaremos un mínimo de funciones de bibliotecas
#     - [SymPy](https://www.sympy.org/es/index.html) para álgebra y análisis simbólico
#     - [NumPy](https://numpy.org/) y [SciPy](https://scipy.org/) para cálculo numérico
#     - [matplotlib](https://matplotlib.org/) para generar representaciones visuales de los resultados

# %% [markdown]
# ## JupyterLab: el entorno de trabajo para esta asignatura

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/screenshot_JupyterLab.png](data:image/png;base64,...)
#
# Captura de pantalla de la resolución de un ejercicio en un cuaderno Jupyter.

# %% [markdown]
# - Los _cuadernos_ de JupyterLab se despliegan en un navegador
# - Están segmentados en celdas de
#     - **anotación**: textos, figuras, multimedia y simbología en notación matemática estándar.
#     - **código**: cálculo simbólico, graficación y simulación numérica.
# - En estos se distribuirá
#     - material teórico
#     - ejemplos de resolución
#     - ejercicios tanto realizados por los docentes
# - Son **reutilizables**, es decir, basta copiarles y modificarles
#     - Así un ejercicio se resuelve modificando ligeramente un ejemplo
#     - Serán así el medio para realizar y entregar ejercicios
#     - Se evita el tiempo perdido copiando pizarrón $\iff$ papel
#     - Cualquier error se corrige y su vuelve a ejecutar el código $\implies$ nunca se empieza desde cero

# %% [markdown]
# ## Los cuadernos se ejecutan en un sistema en línea gratuito

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/comentariosColab.png](data:image/png;base64,...)
#
# Captura de pantalla de la resolución de un ejercicio en Google Colaboratory con comentarios del docente.

# %% [markdown]
# - Para ejecutar cuadernos Jupyter utilizaremos [Google Colaboratory](https://colab.research.google.com/)
#     - **gratuito**
#     - **en línea** (web)
#         - Solo se requiere un navegador para trabajar en los cuadernos
#     - **en la nube**
#         - no hay preocuparse por cargar con archivos
#         - puede trabajarse desde cualquier lugar a cualquier hora
#     - **colaborativo**
#         - Alumno(s) y docente pueden escribir en un mismo cuaderno
#             - Habilita el trabajo grupal **remoto**
#         - También los docentes pueden en cada celda
#             - revisar, editar, comentar y corregir
#             - y pueden hacerlo en forma asincrónica (fuera de hora de clase)

# %% [markdown]
# ## [Aula invertida](https://es.wikipedia.org/wiki/Aula_invertida): cambia el uso del tiempo

# %% [markdown]
# ![../01Vectorial/figuras/diagramaTiempo2.png](data:image/png;base64,...)

# %% [markdown]
# - Teoría
#     - se lee, e intenta aplicar, **antes de la clase**
#     - las dudas se aclaran **en clase**
#     - si surgen nuevas dudas se pueden hacer consultas adicionales **tras la clase**
# - Ejercicios
#     - se inician **antes de la clase**
#     - se terminan **en clase**
#     - correcciones sugeridas por el docente **tras la clase**
#
# | Tiempo    | Modalidad tradicional | Aula invertida |
# | -------- | ------- |------- |
# | Sincrónico con los docentes<br />(en clase)  | Énfasis en la exposición de nueva teoría.<br />Solo un resto para atender consultas. |  Énfasis en terminar ejercicios de la semana.<br /> Cuando hay dificultad con uno el docente está a disposición. |
# | Asincrónico<br />(en casa o donde se pueda) | Una parte es repaso de teoría.<br />La mayor parte es realizar los ejercicios.<br />Cuando hay dificultad con uno no hay docente a quién recurrir. | Buena parte es asimilar nueva teoría.<br /> Iniciar la resolución de ejercicios.

# %% [markdown]
# ## Organización del aula invertida

# %% [markdown]
# - Esta modalidad requiere **mucha regularidad** por parte del alumno
# - Si se espera al encuentro sincrónico (clase) para
#     - leer teoría $\implies$ **no alcanza el tiempo**
#     - empezar los ejercicios $\implies$ **no alcanza el tiempo**
#     - ponerse _al día_ con lo adeudado de la semana panterior $\implies$ **no alcanza el tiempo**
# - Para ayudar a manterse al día habrá una **evaluación semanal**
#     - **Nueva guía** de ejercicios cada semana
#     - **Entrega obligatoria** de dos o más ejercicios vía Teams a las **21:50 hs** en cada encuentro sincrónico
# - Por supuesto que puede fallarse en uno o más de los ejercicios que se entregan.
#     - es posible que haya faltado comprensión sobre algún aspecto de teoría $\implies$ consulta y/o repaso personal de teoría
#     - pero tal falla debe corregirse en una **segunda entrega**.

# %% [markdown]
# ## Gestión del material de la asignatura: todo en línea

# %% [markdown]
# - Un equipo de [Microsoft Teams](https://teams.microsoft.com/) por cuatrimestre
#   - Un canal por tema **nuevo cada semana** con:
#    - **Teoría**: en cuadernos Jupyter
#    - **Ejercicios resueltos**: cuaderno con el código que lo resuelve
#    - **Guía de ejercicios**: pdf en repositorio
#    - **Tarea**: dos o más ejercicios de la guía a entregar 21:50 del día del encuentro sincrónico
#    - **Consultas asincrónicas**
#        - públicas para que otros puedan sacar provecho de las respuestas
#        - realizables 24/7 a través de la App MS Teams
#        - se las responde durante la semana: **no hay que quedar en duda esperando el encuentro sincrónico**
# - Un repositorio en [GitHub](https://github.com/bettachini/UNLaM_MecanicaGeneral/) aloja el mismo material ordenado por tema/semana
# - Todos los cuadernos Jupyter son **reutilizables** y ejecutables en [Google Colaboratory](https://colab.research.google.com/)

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/unCanalTeams.png](data:image/png;base64,...)

# %% [markdown]
# ## Consultas asincrónicas en línea: 24/7

# %% [markdown]
# | Actividad    | Curso tradicional | Aula invertida |
# | -------- | ------- |------- |
# | Presentación de nueva teoría  | Sincrónico | Asincrónico vía Teams |
# | Ejemplos de resolución de ejercicios | Sincrónico | Asincrónico vía Teams |
# | Consultas sobre teoría  | Sincrónico | Asincrónico vía Teams y sincrónico |
# | Presentación de guías de ejercicios  | Sincrónico | Asincrónico vía Teams |
# | Consultas sobre ejercicios  | Sincrónico | Asincrónico vía Teams y sincrónico |
# | Resolución de ejercicios<br />(por el alumno)  | Asincrónico | Asincrónico (primordialmente)<br /> y sincrónico (cierre) |

# %% [markdown]
# ## Evaluación

# %% [markdown]
# | Actividad    | Proporción nota final [%] | Aclaración |
# | -------- | :-------: |------- |
# | Ejercicios  | 60 | (ver debajo) |
# | Participación en foro | 15 | Respuestas que aporten en Teams a consultas de sus compañeros |
# | Ejercicio integrador  | 15 | Resolución y defensa frente a docentes |

# %% [markdown]
# ### Entregas de ejercicios
# - Cada unidad de la materia tiene una guía de ejercicios, de los cuales varios serán solicitados para la entrega, éstos les aparecerán en _Teams_ bajo _Tareas_.
# - Para aprobar la materia DEBEN realizar las entregas semanales de ejercicios.
#
# - Las clases son para consultar y avanzar en los ejercicios, no duden en preguntarnos todo lo que requieran, de forma tal de que puedan aprovecharnos al máximo para evacuar sus dudas.
#     - Es muy importante que aprovechen las clases para las consultas y que también nos escriban por Teams durante la semana consultando lo que no les salga.
# - El día que se presenta la unidad podrán comenzar a mirarlos y resolverlos, tendrán la siguiente clase para realizar consultas adicionales y deberán ser entregados indefectiblemente antes de que comience la siguiente.
#
#
# ### Esquema de entregas
# > La guía de la clase N se publica en la clase N-1 $\rightarrow$ en clase N pueden consultar $\rightarrow$ al finalizar la clase N todos los ejercicios solicitados deben ser entregados.
#
# - hora máxima de entrega en la clase N + 2: figurará en _Teams_
#     - Pasada esta hora $\implies$ ejercicio desaprobado
#     - Por ello es importante que intenten avanzar en ellos, no es necesario que estén perfectos, una vez los envíen se los corregiremos y les pediremos las modificaciones necesarias para que puedan avanzar hasta que lo terminen satisfactoriamente.
#     - Cuando termine la cursada entonces deberían haber logrado hacer TODOS los ejercicios que les enviamos como _Tarea_.
# - Si por no entregar a tiempo un ejercicio lo desaprobaron, de todas formas les vamos a pedir que lo realicen para la semana siguiente y entreguen.
#     - En caso de no hacerlo se sumará otro desaprobado.
# - La nota de las _Tareas_ será un promedio de todos las notas de los ejercicios entregados y formará parte de la nota final de la materia.
